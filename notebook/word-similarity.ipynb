# %% [markdown]
# ## Embedding

# %%
from gensim.test.utils import common_texts, get_tmpfile
from gensim.models import Word2Vec

# %%
model = Word2Vec.load("word-embedding/idwiki_word2vec_200.model")

# %%
model.wv['saya']
# Out:
# array([-3.47914314e+00,  3.08103871e+00,  2.25179982e+00,  2.86292481e+00,
#        -1.27921581e+00, -3.07287216e-01,  2.18553805e+00,  7.28953898e-01,
#        -8.39389801e-01, -6.07805192e-01, -3.21072459e-01, -1.24952897e-01,
#         1.78807771e+00,  7.92049825e-01, -2.06037855e+00, -7.04700649e-01,
#        -2.54478049e+00, -1.21238247e-01, -1.35414088e+00,  2.27989331e-01,
#        -5.50719619e-01, -5.75023770e-01,  2.72262961e-01, -1.19321799e+00,
#         1.60545421e+00,  2.90933752e+00, -2.87332833e-01,  1.31666458e+00,
#        -1.00328028e+00,  9.52168882e-01,  1.89234316e+00,  1.58888185e+00,
#        -1.41735446e+00, -1.05668819e+00, -1.36161411e+00,  9.84659731e-01,
#         5.62235117e-01, -2.90730059e-01, -1.81607223e+00, -5.72828710e-01,
#         1.00076675e+00,  2.68046951e+00, -2.48431253e+00,  1.83356154e+00,
#        -1.09533143e+00, -2.32618690e+00,  1.06799483e+00,  3.81291330e-01,
# ...
